# %%
import pandas as pd

# %%
data = pd.read_csv("organize_hexa.csv",sep=',', header=None)

# %%
data
# Out:
#            0          1          2
# 0       ce11  23.150052  27.379030
# 1    sacCer3  19.944134   5.550903
# 2    ailMel1  18.755696   3.123786
# 3    anoCar2  19.327992   6.557941
# 4    anoGam3  23.404031  35.575336
# ..       ...        ...        ...
# 90   melGal5  21.073101   9.750675
# 91       rn7  26.675407  23.536699
# 92  xenTro10  19.915928  13.350108
# 93      hg38  19.662187   6.487214
# 94      mm39  31.157092  32.514758
#
# [95 rows x 3 columns]

# %%
data.columns = ['species','mean','std']
data.head(21)
# Out:
#         species       mean        std
# 0          ce11  23.150052  27.379030
# 1       sacCer3  19.944134   5.550903
# 2       ailMel1  18.755696   3.123786
# 3       anoCar2  19.327992   6.557941
# 4       anoGam3  23.404031  35.575336
# 5       apiMel2  19.233850   6.771241
# 6       aplCal1  20.227922   7.302742
# 7       aptMan1  20.104742  12.547365
# 8       aquChr2  20.691836   7.366756
# 9       balAcu1  19.067177   4.764972
# 10      braFlo1  20.536138  10.399181
# 11       caePb2  20.206549  15.367461
# 12      caeJap1  18.870968   3.460506
# 13      caeRem3  20.418367  19.128685
# 14      calMil1  19.060703   7.983018
# 15      cavPor3  21.671498   9.296263
# 16      cerSim1  19.305830   5.478671
# 17      chlSab2  19.620513   4.942707
# 18      choHof1  19.313454   4.641094
# 19      chrPic1  19.126361   4.369857
# 20  criGriChoV2  23.438185  13.819878

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure
import matplotlib
fig = matplotlib.pyplot.gcf()
figure(figsize=(20, 15), dpi=80)
fig.set_size_inches(50, 30, forward=True)
x = range(len(data['species']))
plt.errorbar(x, data['mean'], yerr = data['std'],fmt='sk',
              elinewidth=1,lw=10, capsize=0)
plt.xticks(x, data['species'],fontsize=14, rotation=90)
plt.yticks(fontsize=14)

plt.grid()
N=150
plt.gca().margins(x=0.01)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*N+2*m
margin = m/plt.gcf().get_size_inches()[0]

#plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])

fig.subplots_adjust(bottom=0.7)
plt.title('Mean and Standard Deviation for the Length of Hexanucleotides', fontdict = {'fontsize' : 40})
plt.savefig("Hexanucleotide.png",dpi=300)
plt.show()

# %%
data[0].str.split(',', expand=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-49dfede90301> in <module>
# ----> 1 data[0].str.split(',', expand=True)
#
# ...

# %%
data = data.fillna(0)

# %%
data = data.drop(data.index[0])

# %%
import statistics
from statistics import mean
mean(data.iloc[:,94])
  

xval = list(data.columns)
yval = []
std = []
for i in range(0,95):
    cur = mean(data.iloc[:,i])
    yval.append(cur)
    s = statistics.pstdev(data.iloc[:,i])
    std.append(s)
